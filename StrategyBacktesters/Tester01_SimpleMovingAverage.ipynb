# %%
from SimpleMovingAverageBT import SimpleMovingAverageBT as BT

# %% [markdown]
# ### Testing instantiation, getting data, plotting, setting new SMA window

# %%
tester = BT("AAPL", 50, 200, "2004-01-01", "2020-07-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.ptc #estimated cost per trade
# Out:
# 1.5852400980477577e-06

# %%
tester.data
# Out:
#                 Price   returns     SMA_S      SMA_L
# Date
# 2004-01-02   0.380000       NaN       NaN        NaN
# 2004-01-05   0.395893  0.040973       NaN        NaN
# 2004-01-06   0.394464 -0.003616       NaN        NaN
# 2004-01-07   0.403393  0.022383       NaN        NaN
# 2004-01-08   0.417143  0.033518       NaN        NaN
# ...               ...       ...       ...        ...
# 2020-06-24  90.014999 -0.017810  78.69500  70.117500
# 2020-06-25  91.209999  0.013188  79.09705  70.302675
# 2020-06-26  88.407501 -0.031208  79.43175  70.465225
# 2020-06-29  90.445000  0.022785  79.82665  70.638587
# 2020-06-30  91.199997  0.008313  80.26600  70.821150
#
# [4152 rows x 4 columns]

# %%
tester.backtest()
# Out:
# SMA Net performance: 23.0345 || SMA outperformance vs Buy and Hold: -83.9225

# %%
tester.result.trades.value_counts() # execute a total of 12 trades, so we dont trade very often!
# Out:
# trades
# 0.0    3940
# 2.0      12
# Name: count, dtype: int64

# %%
tester.data
# Out:
#                 Price   returns     SMA_S      SMA_L
# Date
# 2004-01-02   0.380000       NaN       NaN        NaN
# 2004-01-05   0.395893  0.040973       NaN        NaN
# 2004-01-06   0.394464 -0.003616       NaN        NaN
# 2004-01-07   0.403393  0.022383       NaN        NaN
# 2004-01-08   0.417143  0.033518       NaN        NaN
# ...               ...       ...       ...        ...
# 2020-06-24  90.014999 -0.017810  78.69500  70.117500
# 2020-06-25  91.209999  0.013188  79.09705  70.302675
# 2020-06-26  88.407501 -0.031208  79.43175  70.465225
# 2020-06-29  90.445000  0.022785  79.82665  70.638587
# 2020-06-30  91.199997  0.008313  80.26600  70.821150
#
# [4152 rows x 4 columns]

# %%
trades = tester.result.positions.diff().fillna(0).abs()
trades.value_counts()
# Out:
# positions
# 0.0    3940
# 2.0      12
# Name: count, dtype: int64

# %%
tester.plot_data()

# %%
tester.set_window(36,174)

# %%
tester.backtest()
# Out:
# SMA Net performance: 20.3956 || SMA outperformance vs Buy and Hold: -121.9852

# %%
tester.plot_data()

# %%
tester.result
# Out:
#                 Price   returns      SMA_S      SMA_L  positions  r_strategy  \
# Date
# 2004-09-13   0.635536 -0.007837   0.583398   0.501821          1   -0.007837
# 2004-09-14   0.633750 -0.002814   0.585774   0.503188          1   -0.002814
# 2004-09-15   0.628571 -0.008206   0.587728   0.504533          1   -0.008206
# 2004-09-16   0.649107  0.032149   0.589673   0.505945          1    0.032149
# 2004-09-17   0.663214  0.021500   0.592088   0.507359          1    0.021500
# ...               ...       ...        ...        ...        ...         ...
# 2020-06-24  90.014999 -0.017810  81.806736  72.244741          1   -0.017810
# 2020-06-25  91.209999  0.013188  82.273958  72.432198          1    0.013188
# 2020-06-26  88.407501 -0.031208  82.642014  72.602241          1   -0.031208
# 2020-06-29  90.445000  0.022785  83.045069  72.782371          1    0.022785
# 2020-06-30  91.199997  0.008313  83.424722  72.960948          1    0.008313
#
#               creturns  cr_strategy
# Date
# 2004-09-13    0.992194     0.992194
# 2004-09-14    0.989406     0.989406
# 2004-09-15    0.981320     0.981320
# 2004-09-16    1.013381     1.013381
# 2004-09-17    1.035405     1.035405
# ...                ...          ...
# 2020-06-24  140.530740    20.131597
# 2020-06-25  142.396364    20.398855
# 2020-06-26  138.021126    19.772084
# 2020-06-29  141.202053    20.227765
# 2020-06-30  142.380749    20.396618
#
# [3978 rows x 8 columns]

# %%
tester.data
# Out:
#                 Price   returns      SMA_S      SMA_L
# Date
# 2004-01-02   0.380000       NaN        NaN        NaN
# 2004-01-05   0.395893  0.040973        NaN        NaN
# 2004-01-06   0.394464 -0.003616        NaN        NaN
# 2004-01-07   0.403393  0.022383        NaN        NaN
# 2004-01-08   0.417143  0.033518        NaN        NaN
# ...               ...       ...        ...        ...
# 2020-06-24  90.014999 -0.017810  81.806736  72.244741
# 2020-06-25  91.209999  0.013188  82.273958  72.432198
# 2020-06-26  88.407501 -0.031208  82.642014  72.602241
# 2020-06-29  90.445000  0.022785  83.045069  72.782371
# 2020-06-30  91.199997  0.008313  83.424722  72.960948
#
# [4152 rows x 4 columns]

# %%
print(tester)
# Out:
# SimpleMovingAverageBT: AAPL, Short window = 36, Long window = 174

# %% [markdown]
# ### Testing window optimisation method

# %%
tester.optimise_windows((10,100,1), (100,252,1))
# Out:
# Optimal Window(short, long) : 11,207 || Performance : 84.386

# %%
tester.optimise_windows((10,50,1),(100,252,1))
# Out:
# Optimal Window(short, long) : 46,137 || Performance : 2.5267

# %%
tester.set_window(11,207)

# %%
tester.backtest()
tester.plot_data()
# Out:
# SMA absolute performance: 84.386 || SMA outperformance vs Buy and Hold: -17.1488

# %% [markdown]
# Optimisation improves the strategy performance, but does not beat buy and hold.

# %% [markdown]
# ### Testing on another stock - Bitcoin

# %%
tester2 = BT("BTC-USD", 50, 200, "2004-01-01", "2020-07-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester2.ptc
# Out:
# 1.3459514662558232e-09

# %%
tester2.backtest()
# Out:
# SMA Net performance: 12.7445 || SMA outperformance vs Buy and Hold: -23.2749

# %%
tester2.result.trades.value_counts() #only change positions 9 times!
# Out:
# trades
# 0.0    1905
# 2.0       9
# Name: count, dtype: int64

# %%
tester2.plot_data()

# %%
tester2.optimise_windows((10,100,1), (100,252,1))
# Out:
# Optimal Window(short, long) : 99,178 || Performance : 176.2725

# %%
tester2.set_window(99,178)

# %%
tester2.backtest()
# Out:
# SMA Net performance: 176.2725 || SMA outperformance vs Buy and Hold: 144.2472

# %%
tester2.plot_data()

# %% [markdown]
# Price trends generally match buy and hold in the earlier years, significantly greater returns seen after 2019

# %% [markdown]
# Effects of trading costs are negligible since we barely trade
